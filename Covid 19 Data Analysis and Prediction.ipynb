# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('owid-covid-data.csv')
data.head(10)
# Out:
#   iso_code      continent location        date  total_cases  new_cases  \
# 0      ABW  North America    Aruba  13-03-2020          2.0        2.0
# 1      ABW  North America    Aruba  20-03-2020          4.0        2.0
# 2      ABW  North America    Aruba  24-03-2020         12.0        8.0
# 3      ABW  North America    Aruba  25-03-2020         17.0        5.0
# 4      ABW  North America    Aruba  26-03-2020         19.0        2.0
# 5      ABW  North America    Aruba  27-03-2020         28.0        9.0
# 6      ABW  North America    Aruba  28-03-2020         28.0        0.0
# 7      ABW  North America    Aruba  29-03-2020         28.0        0.0
# 8      ABW  North America    Aruba  30-03-2020         50.0       22.0
# 9      ABW  North America    Aruba  01-04-2020         55.0        5.0
#
#    total_deaths  new_deaths  total_cases_per_million  new_cases_per_million  \
# 0           0.0         0.0                   18.733                 18.733
# ...

# %% [markdown]
# # Subsetting rows which have India as the location

# %%
df=data[data['location']=='India']

# %%
df.head(10)
# Out:
#       iso_code continent location        date  total_cases  new_cases  \
# 15033      IND      Asia    India  31-12-2019          0.0        0.0
# 15034      IND      Asia    India  01-01-2020          0.0        0.0
# 15035      IND      Asia    India  02-01-2020          0.0        0.0
# 15036      IND      Asia    India  03-01-2020          0.0        0.0
# 15037      IND      Asia    India  04-01-2020          0.0        0.0
# 15038      IND      Asia    India  05-01-2020          0.0        0.0
# 15039      IND      Asia    India  06-01-2020          0.0        0.0
# 15040      IND      Asia    India  07-01-2020          0.0        0.0
# 15041      IND      Asia    India  08-01-2020          0.0        0.0
# 15042      IND      Asia    India  09-01-2020          0.0        0.0
#
#        total_deaths  new_deaths  total_cases_per_million  \
# 15033           0.0         0.0                      0.0
# 15034           0.0         0.0                      0.0
# ...

# %%
df.shape
# Out:
# (219, 36)

# %%
df.describe().transpose() # to check the min max and other details of the information
# Out:
#                                  count          mean           std  \
# total_cases                      219.0  2.585647e+05  4.565213e+05
# new_cases                        219.0  8.970484e+03  1.470043e+04
# total_deaths                     219.0  6.610406e+03  1.065749e+04
# new_deaths                       219.0  1.858402e+02  2.772205e+02
# total_cases_per_million          219.0  1.873651e+02  3.308115e+02
# new_cases_per_million            219.0  6.500324e+00  1.065242e+01
# total_deaths_per_million         219.0  4.790137e+00  7.722785e+00
# new_deaths_per_million           219.0  1.346575e-01  2.008610e-01
# new_tests                        129.0  1.706548e+05  1.524172e+05
# total_tests                      135.0  5.831065e+06  6.025422e+06
# total_tests_per_thousand         135.0  4.225422e+00  4.366202e+00
# new_tests_per_thousand           129.0  1.236822e-01  1.105070e-01
# new_tests_smoothed               140.0  1.455537e+05  1.365246e+05
# ...

# %%
# Finding information of null values in Dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 219 entries, 15033 to 15251
# Data columns (total 36 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   iso_code                         219 non-null    object
#  1   continent                        219 non-null    object
#  2   location                         219 non-null    object
#  3   date                             219 non-null    object
#  4   total_cases                      219 non-null    float64
#  5   new_cases                        219 non-null    float64
#  6   total_deaths                     219 non-null    float64
#  7   new_deaths                       219 non-null    float64
#  8   total_cases_per_million          219 non-null    float64
#  9   new_cases_per_million            219 non-null    float64
#  10  total_deaths_per_million         219 non-null    float64
# ...

# %%
df.isna().sum()
# Out:
# iso_code                            0
# continent                           0
# location                            0
# date                                0
# total_cases                         0
# new_cases                           0
# total_deaths                        0
# new_deaths                          0
# total_cases_per_million             0
# new_cases_per_million               0
# total_deaths_per_million            0
# new_deaths_per_million              0
# new_tests                          90
# total_tests                        84
# total_tests_per_thousand           84
# new_tests_per_thousand             90
# new_tests_smoothed                 79
# new_tests_smoothed_per_thousand    79
# tests_per_case                     79
# positive_rate                      79
# tests_units                        72
# stringency_index                   14
# population                          0
# population_density                  0
# median_age                          0
# ...

# %%
#we see that in certain data we have null values
#we need to handle the null values

# %%
df.fillna(df.mean(),inplace=True)
# Out:
# C:\Users\MD AREEB  AKHTAR\AppData\Local\Temp\ipykernel_16984\2085774198.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean(),inplace=True)
# C:\Users\MD AREEB  AKHTAR\AppData\Local\Temp\ipykernel_16984\2085774198.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.fillna(df.mean(),inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 219 entries, 15033 to 15251
# Data columns (total 36 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   iso_code                         219 non-null    object
#  1   continent                        219 non-null    object
#  2   location                         219 non-null    object
#  3   date                             219 non-null    object
#  4   total_cases                      219 non-null    float64
#  5   new_cases                        219 non-null    float64
#  6   total_deaths                     219 non-null    float64
#  7   new_deaths                       219 non-null    float64
#  8   total_cases_per_million          219 non-null    float64
#  9   new_cases_per_million            219 non-null    float64
#  10  total_deaths_per_million         219 non-null    float64
# ...

# %% [markdown]
# # Data Analysis

# %% [markdown]
# # Univariate Data Analysis

# %%
import seaborn as sns

# %%
sns.set()
plt.hist(df['new_cases'], color='grey', edgecolor='black', linewidth=1)
plt.title('Plot showing New Cases')
plt.xlabel('New Cases')
plt.ylabel('Frequency')
plt.show()

# %%
sns.set()
plt.hist(df['new_tests'], color='yellow', edgecolor='black', linewidth=1)
plt.title('Plot showing New Tests')
plt.xlabel('New Tests')
plt.ylabel('Frequency')
plt.show()

# %%
sns.set()
plt.hist(df['new_deaths'], color='lightcoral', edgecolor='black', linewidth=1)
plt.title('Plot showing New Deaths')
plt.xlabel('New Deaths')
plt.ylabel('Frequency')
plt.show()

# %%
sns.set()
plt.hist(df['total_deaths'], color='bisque', edgecolor='black', linewidth=1)
plt.title('Plot showing Number of Total Deaths')
plt.xlabel('Number of total deaths per day')
plt.ylabel('Frequency')
plt.show()

# %%
sns.set()
plt.hist(df['tests_per_case'], color='greenyellow', edgecolor='black', linewidth=1)
plt.title('Plot showing Tests per Case')
plt.xlabel('Number of tests per case')
plt.ylabel('Frequency')
plt.show()

# %%
sns.set()
plt.hist(df['positive_rate'], color='palegreen', edgecolor='black', linewidth=1)
plt.title('Plot showing Positive Rate')
plt.xlabel('Positive rate per day')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Printing the Mean Median and Mode

# %%
print(df.mean())
# Out:
# total_cases                        2.585647e+05
# new_cases                          8.970484e+03
# total_deaths                       6.610406e+03
# new_deaths                         1.858402e+02
# total_cases_per_million            1.873651e+02
# new_cases_per_million              6.500324e+00
# total_deaths_per_million           4.790137e+00
# new_deaths_per_million             1.346575e-01
# new_tests                          1.706548e+05
# total_tests                        5.831065e+06
# total_tests_per_thousand           4.225422e+00
# new_tests_per_thousand             1.236822e-01
# new_tests_smoothed                 1.455537e+05
# new_tests_smoothed_per_thousand    1.054714e-01
# tests_per_case                     1.824934e+01
# positive_rate                      6.577857e-02
# stringency_index                   5.686171e+01
# population                         1.380004e+09
# population_density                 4.504190e+02
# median_age                         2.820000e+01
# ...

# %%
print(df.median())
# Out:
# total_cases                        1.571200e+04
# new_cases                          1.334000e+03
# total_deaths                       5.070000e+02
# new_deaths                         3.800000e+01
# total_cases_per_million            1.138500e+01
# new_cases_per_million              9.670000e-01
# total_deaths_per_million           3.670000e-01
# new_deaths_per_million             2.800000e-02
# new_tests                          1.706548e+05
# total_tests                        5.831065e+06
# total_tests_per_thousand           4.225422e+00
# new_tests_per_thousand             1.236822e-01
# new_tests_smoothed                 1.455537e+05
# new_tests_smoothed_per_thousand    1.054714e-01
# tests_per_case                     1.824934e+01
# positive_rate                      6.577857e-02
# stringency_index                   7.546000e+01
# population                         1.380004e+09
# population_density                 4.504190e+02
# median_age                         2.820000e+01
# ...

# %%
print(df.mode().transpose())
# Out:
#                                             0           1           2    \
# iso_code                                    IND         NaN         NaN
# continent                                  Asia         NaN         NaN
# location                                  India         NaN         NaN
# date                                 01-01-2020  01-02-2020  01-03-2020
# total_cases                                 0.0         NaN         NaN
# new_cases                                   0.0         NaN         NaN
# total_deaths                                0.0         NaN         NaN
# new_deaths                                  0.0         NaN         NaN
# total_cases_per_million                     0.0         NaN         NaN
# new_cases_per_million                       0.0         NaN         NaN
# total_deaths_per_million                    0.0         NaN         NaN
# new_deaths_per_million                      0.0         NaN         NaN
# ...

# %% [markdown]
# # Bivariate Data Analysis

# %% [markdown]
# ## Scatter Plots and Line Plots

# %%
sns.set()
plt.scatter(df['new_deaths'].values, df['total_cases'].values, s = 20, c = 'red')
plt.xlabel('Number of New Deaths')
plt.ylabel('Number of Total Cases')
plt.title('Total Cases Vs New Deaths')
plt.margins(0.02)
plt.show()

# %%
sns.set()
plt.scatter(df['total_deaths'].values,df['total_cases'].values, s = 20, c = 'white',edgecolors='black')
plt.xlabel('Number of Total Deaths')
plt.ylabel('Number of Total Cases')
plt.title('Total Cases Vs Total Deaths')
plt.margins(0.02)
plt.show()

# %%
sns.set()
plt.scatter(df['total_tests'].values, df['total_cases'].values, s = 20, c='white',edgecolors='purple')
plt.xlabel('Number of Total Tests')
plt.ylabel('Number of Total Cases')
plt.title('Total Cases Vs Total Tests')
plt.margins(0.02)
plt.show()

# %%
sns.set()
plt.scatter(df['new_tests_smoothed'].values, df['total_cases'].values, s = 20, c = 'mediumspringgreen',edgecolors='orange')
plt.xlabel('New Tests Smoothed')
plt.ylabel('Number of Total Cases')
plt.title('Total Cases Vs New Tests Smoothed')
plt.margins(0.02)
plt.show()

# %%
sns.set()
plt.scatter(df['gdp_per_capita'].values, df['total_cases'].values, s = 20, c = 'black',edgecolors='green')
plt.xlabel('GDP per Capita')
plt.ylabel('Number of Total Cases')
plt.title('Total Cases Vs GDP per Capita')
plt.margins(0.02)
plt.show()

# %%
sns.set()
plt.plot(df['new_tests_smoothed'].values, df['total_cases'].values, c = 'black')
plt.xlabel('New Tests Smoothed')
plt.ylabel('Number of Total Cases')
plt.title('Total Cases Vs New Tests Smoothed')
plt.margins(0.02)
plt.show()

# %%
sns.set()
plt.plot(df['total_tests'].values, df['total_cases'].values, c='blue')
plt.xlabel('Number of Total Tests')
plt.ylabel('Number of Total Cases')
plt.title('Total Cases Vs Total Tests')
plt.margins(0.02)
plt.show()

# %% [markdown]
# # Converting Date and time to ordinal

# %%
# Importing datetime and converting date column to ordinal form
import datetime as dt
df.loc[:,'date'] = pd.to_datetime(df['date'])
df.loc[:,'date'] = df['date'].map(dt.datetime.toordinal)
# Out:
# C:\Users\MD AREEB  AKHTAR\AppData\Local\Temp\ipykernel_16984\583365058.py:3: UserWarning: Parsing '31-12-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df.loc[:,'date'] = pd.to_datetime(df['date'])
# C:\Users\MD AREEB  AKHTAR\AppData\Local\Temp\ipykernel_16984\583365058.py:3: UserWarning: Parsing '13-01-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df.loc[:,'date'] = pd.to_datetime(df['date'])
# C:\Users\MD AREEB  AKHTAR\AppData\Local\Temp\ipykernel_16984\583365058.py:3: UserWarning: Parsing '14-01-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df.loc[:,'date'] = pd.to_datetime(df['date'])
# C:\Users\MD AREEB  AKHTAR\AppData\Local\Temp\ipykernel_16984\583365058.py:3: UserWarning: Parsing '15-01-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
# ...

# %% [markdown]
# # Data Filtering

# %%
use_df=df.drop(['iso_code','continent','location','tests_units','new_deaths','total_deaths','total_deaths_per_million','new_deaths_per_million'],axis=1)
#after dropping we can see the basic details of the useful data
use_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 219 entries, 15033 to 15251
# Data columns (total 28 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   date                             219 non-null    int64
#  1   total_cases                      219 non-null    float64
#  2   new_cases                        219 non-null    float64
#  3   total_cases_per_million          219 non-null    float64
#  4   new_cases_per_million            219 non-null    float64
#  5   new_tests                        219 non-null    float64
#  6   total_tests                      219 non-null    float64
#  7   total_tests_per_thousand         219 non-null    float64
#  8   new_tests_per_thousand           219 non-null    float64
#  9   new_tests_smoothed               219 non-null    float64
#  10  new_tests_smoothed_per_thousand  219 non-null    float64
# ...

# %%
use_df.drop('total_cases_per_million',axis=1)#we are dropping the total cases per million so that we can 
#only predict the total cases and let not the the total cases per million affect our prediction model
# Out:
#          date  total_cases  new_cases  new_cases_per_million      new_tests  \
# 15033  737424          0.0        0.0                  0.000  170654.751938
# 15034  737425          0.0        0.0                  0.000  170654.751938
# 15035  737456          0.0        0.0                  0.000  170654.751938
# 15036  737485          0.0        0.0                  0.000  170654.751938
# 15037  737516          0.0        0.0                  0.000  170654.751938
# ...       ...          ...        ...                    ...            ...
# 15247  737463    1750723.0    54735.0                 39.663  463172.000000
# 15248  737492    1803695.0    52972.0                 38.385  381027.000000
# 15249  737523    1855745.0    52050.0                 37.717  661892.000000
# 15250  737553    1908254.0    52509.0                 38.050  619652.000000
# 15251  737584    1964536.0    56282.0                 40.784  664949.000000
#
# ...

# %%
use_df.describe().transpose()
# Out:
#                                  count          mean           std  \
# date                             219.0  7.375576e+05  8.628463e+01
# total_cases                      219.0  2.585647e+05  4.565213e+05
# new_cases                        219.0  8.970484e+03  1.470043e+04
# total_cases_per_million          219.0  1.873651e+02  3.308115e+02
# new_cases_per_million            219.0  6.500324e+00  1.065242e+01
# new_tests                        219.0  1.706548e+05  1.167914e+05
# total_tests                      219.0  5.831065e+06  4.724019e+06
# total_tests_per_thousand         219.0  4.225422e+00  3.423166e+00
# new_tests_per_thousand           219.0  1.236822e-01  8.467721e-02
# new_tests_smoothed               219.0  1.455537e+05  1.090160e+05
# new_tests_smoothed_per_thousand  219.0  1.054714e-01  7.899672e-02
# tests_per_case                   219.0  1.824934e+01  6.847969e+00
# positive_rate                    219.0  6.577857e-02  2.153151e-02
# ...

# %%
use_df.shape
# Out:
# (219, 28)

# %% [markdown]
# # Splitting the data into features and target data

# %%
y=use_df['total_cases']

# %%
X=use_df.drop(['total_cases','total_cases_per_million'],axis=1)#we are dropping

# %% [markdown]
# # Performing train-test split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
X_train.shape
# Out:
# (153, 26)

# %%
X_test.shape
# Out:
# (66, 26)

# %%
y_train.shape
# Out:
# (153,)

# %%
y_test.shape
# Out:
# (66,)

# %%
print("training data of features columns")
X_train.head(5)
# Out:
# training data of features columns
#          date  new_cases  new_cases_per_million      new_tests   total_tests  \
# 15195  737735     9996.0                  7.243  151808.000000  5.213140e+06
# 15098  737548       22.0                  0.016  170654.751938  5.831065e+06
# 15144  737536     1335.0                  0.967  170654.751938  4.626210e+05
# 15218  737522    22771.0                 16.501  242383.000000  9.540132e+06
# 15210  737602    17296.0                 12.533  215446.000000  7.776228e+06
#
#        total_tests_per_thousand  new_tests_per_thousand  new_tests_smoothed  \
# 15195                  3.778000                0.110000       138632.000000
# 15098                  4.225422                0.123682       145553.685714
# 15144                  0.335000                0.123682        31104.000000
# 15218                  6.913000                0.176000       220489.000000
# 15210                  5.635000                0.156000       192800.000000
#
# ...

# %%
print("testing data of features columns")
X_test.head(5)
# Out:
# testing data of features columns
#          date  new_cases  new_cases_per_million      new_tests   total_tests  \
# 15187  737490     8909.0                  6.456  137158.000000  4.103233e+06
# 15126  737488      336.0                  0.243   21294.000000  6.924500e+04
# 15249  737523    52050.0                 37.717  661892.000000  2.086475e+07
# 15250  737553    52509.0                 38.050  619652.000000  2.148440e+07
# 15048  737439        0.0                  0.000  170654.751938  5.831065e+06
#
#        total_tests_per_thousand  new_tests_per_thousand  new_tests_smoothed  \
# 15187                  2.973000                0.099000       123010.000000
# 15126                  0.050000                0.015000         5937.000000
# 15249                 15.119000                0.480000       504266.000000
# 15250                 15.568000                0.449000       534380.000000
# 15048                  4.225422                0.123682       145553.685714
#
# ...

# %%
print("training data of target column")
y_train.head(5)
# Out:
# training data of target column
# 15195    286579.0
# 15098        28.0
# 15144     18600.0
# 15218    648315.0
# 15210    490401.0
# Name: total_cases, dtype: float64

# %%
print("testing data of target column")
y_test.head(5)
# Out:
# testing data of target column
# 15187     207615.0
# 15126       2301.0
# 15249    1855745.0
# 15250    1908254.0
# 15048          0.0
# Name: total_cases, dtype: float64

# %% [markdown]
# # Data Modelling

# %% [markdown]
# # Implementing Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
mod=LinearRegression()
mod.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Printing Accuracy of Linear Regression Model

# %%
accuracy =mod.score(X_test,y_test)*100
print("the accuracy of model is: ",accuracy,"%")
# Out:
# the accuracy of model is:  99.21729571142609 %

# %% [markdown]
# # Implementing Linear Regression

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfg=RandomForestRegressor()
rfg.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %% [markdown]
# # Printing Accuracy of Random Forest Regressor

# %%
accu=rfg.score(X_test,y_test)*100
print("the accuracy of random forest generator: ",accu,"%")
# Out:
# the accuracy of random forest generator:  99.78829361727885 %

# %% [markdown]
# # Now, Time To Predict !!!

# %%
# I have created a CSV File using mean values of all the columns except for the Date column
# We have to predict the total number of cases on a given date
# Importing the File
pre=pd.read_csv('predict.csv')

# %%
pre.head()
# Out:
#          date  new_cases  total_deaths  new_deaths  total_cases_per_million  \
# 0  10-08-2020       8970          6610         185                      187
#
#    new_cases_per_million  total_deaths_per_million  new_deaths_per_million  \
# 0                6.50032                  4.790137                0.134658
#
#    new_tests  total_tests  ...  aged_70_older  gdp_per_capita  \
# 0     170654      5831065  ...          3.414         6426.67
#
#    extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 0             21.2                 282.28                10.39
#
#    female_smokers  male_smokers  handwashing_facilities  \
# 0             1.9          20.6                   59.55
#
#    hospital_beds_per_thousand  life_expectancy
# 0                        0.53            69.66
#
# [1 rows x 31 columns]

# %%
pre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 31 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   date                             1 non-null      object
#  1   new_cases                        1 non-null      int64
#  2   total_deaths                     1 non-null      int64
#  3   new_deaths                       1 non-null      int64
#  4   total_cases_per_million          1 non-null      int64
#  5   new_cases_per_million            1 non-null      float64
#  6   total_deaths_per_million         1 non-null      float64
#  7   new_deaths_per_million           1 non-null      float64
#  8   new_tests                        1 non-null      int64
#  9   total_tests                      1 non-null      int64
#  10  total_tests_per_thousand         1 non-null      float64
#  11  new_tests_per_thousand           1 non-null      float64
# ...

# %%
pre=pre.drop(['total_cases_per_million','new_deaths','total_deaths','total_deaths_per_million','new_deaths_per_million'],axis=1)

# %% [markdown]
# # Changing Date Time to ordinal

# %%
import datetime as dt
pre.loc[:,'date']=pd.to_datetime(pre['date'])
pre.loc[:,'date']=pre.loc[:,'date'].map(pd.datetime.toordinal)
# Out:
# C:\Users\MD AREEB  AKHTAR\AppData\Local\Temp\ipykernel_16984\1672019885.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   pre.loc[:,'date']=pre.loc[:,'date'].map(pd.datetime.toordinal)

# %%
pre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 26 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   date                             1 non-null      int64
#  1   new_cases                        1 non-null      int64
#  2   new_cases_per_million            1 non-null      float64
#  3   new_tests                        1 non-null      int64
#  4   total_tests                      1 non-null      int64
#  5   total_tests_per_thousand         1 non-null      float64
#  6   new_tests_per_thousand           1 non-null      float64
#  7   new_tests_smoothed               1 non-null      int64
#  8   new_tests_smoothed_per_thousand  1 non-null      float64
#  9   tests_per_case                   1 non-null      float64
#  10  positive_rate                    1 non-null      float64
#  11  stringency_index                 1 non-null      float64
# ...

# %% [markdown]
# # Predicting total cases using the data i built

# %%
print("predicting total cases using linear regression :",(int)(mod.predict(pre)[0]))
# Out:
# predicting total cases using linear regression : 190513

# %%
print("predicting total cases using random forest generator :",(int)(rfg.predict(pre)[0]))
# Out:
# predicting total cases using random forest generator : 216686
